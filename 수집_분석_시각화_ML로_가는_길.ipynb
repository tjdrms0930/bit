# %% [markdown]
# <a href="https://colab.research.google.com/github/tjdrms0930/bit/blob/main/%EC%88%98%EC%A7%91_%EB%B6%84%EC%84%9D_%EC%8B%9C%EA%B0%81%ED%99%94_ML%EB%A1%9C_%EA%B0%80%EB%8A%94_%EA%B8%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * 경사하강법을 이용한 선형 회귀

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
xs = [[2],[4],[9],[5],[3],[6]] # 특성이 하나로 구성된 독립변수 목록
ys = [8,12,31,15,12,20] # 종속변수 목록

# %%
plt.figure(figsize=(4,4))
plt.plot(xs[:],ys,'o',label="sample data")
plt.xlim(0,30)
plt.ylim(0,30) 
plt.legend()
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.plot(xs[:],ys,'o',label="sample data")
plt.plot([0,20],[2,42],label='y=2x+2')
plt.plot([0,20],[2,62],label='y=3x+2')
plt.plot([0,20],[2,82],label='y=4x+2')
plt.xlim(0,30)
plt.ylim(0,30)
plt.legend()
plt.show()

# %% [markdown]
# * 손실함수
#
# 실제 값과 예측 값의 차이를 손실(오차)라고 한다.
#
#
# 손실함수는 손실을 계산하는 함수로 평균(절대값(예측값 - 실제값)) 방식과
#
# 평균((예측값-실제값)*(예측값-실제값)) 방식을 가장 선호한다.

# %%
def mse(yp,y): #mean squared error
  return np.mean((yp-y)**2)

# %%
nys = np.array(ys)
nysp1 = np.array([ 2*x[0]+2 for x in xs[:]])
nysp2 = np.array([ 3*x[0]+2 for x in xs[:]])
nysp3 = np.array([ 4*x[0]+2 for x in xs[:]])
print(mse(nysp1,nys))
print(mse(nysp2,nys))
print(mse(nysp3,nys))
# Out:
# 31.666666666666668
# 2.1666666666666665
# 29.666666666666668

# %% [markdown]
# * 가중치를 바꿔가면서 mse 계산해 보기

# %%
ws = [w10/10 for w10 in range(-30,80)]
b = 2 #편향은 2로 가정하자.
x1 = [x[0] for x in xs]
mses = []
for w in ws:
  yp = np.array([w*x+b for x in x1])
  mses.append(mse(yp,nys))
print(mses)
# Out:
# [1034.1666666666667, 1000.1516666666665, 966.7066666666668, 933.8316666666666, 901.5266666666668, 869.7916666666666, 838.6266666666666, 808.0316666666668, 778.0066666666667, 748.5516666666668, 719.6666666666666, 691.3516666666666, 663.6066666666667, 636.4316666666665, 609.8266666666667, 583.7916666666666, 558.3266666666667, 533.4316666666667, 509.1066666666666, 485.35166666666663, 462.1666666666667, 439.5516666666667, 417.5066666666667, 396.0316666666666, 375.1266666666667, 354.7916666666667, 335.02666666666664, 315.83166666666665, 297.2066666666667, 279.15166666666664, 261.6666666666667, 244.75166666666667, 228.40666666666664, 212.63166666666666, 197.42666666666665, 182.79166666666666, 168.72666666666666, 155.23166666666665, 142.30666666666667, 129.95166666666665, 118.16666666666667, 106.95166666666667, 96.30666666666669, 86.23166666666664, 76.72666666666667, 67.79166666666667, 59.426666666666655, 51.63166666666669, 44.406666666666666, 37.75166666666667, 31.666666666666668, 26.151666666666657, 21.20666666666666, 16.831666666666674, 13.026666666666676, 9.791666666666666, 7.126666666666661, 5.031666666666663, 3.5066666666666695, 2.551666666666669, 2.1666666666666665, 2.351666666666666, 3.106666666666669, 4.431666666666664, 6.326666666666662, 8.791666666666666, 11.826666666666666, 15.431666666666679, 19.60666666666665, 24.35166666666667, 29.666666666666668, 35.551666666666655, 42.00666666666669, 49.031666666666645, 56.62666666666669, 64.79166666666667, 73.52666666666666, 82.83166666666669, 92.70666666666664, 103.15166666666669, 114.16666666666667, 125.75166666666661, 137.90666666666672, 150.6316666666666, 163.9266666666667, 177.79166666666666, 192.2266666666666, 207.2316666666667, 222.80666666666662, 238.9516666666667, 255.66666666666666, 272.9516666666666, 290.80666666666673, 309.2316666666666, 328.22666666666674, 347.7916666666667, 367.9266666666667, 388.6316666666667, 409.9066666666666, 431.7516666666667, 454.1666666666667, 477.1516666666667, 500.70666666666665, 524.8316666666667, 549.5266666666668, 574.7916666666666, 600.6266666666664, 627.0316666666666, 654.0066666666667, 681.5516666666668]

# %%
n_mses = np.array(mses)
mi = np.argmin(n_mses)
plt.plot(ws,mses,label='w,mse')
plt.plot(ws[mi], mses[mi],'ro',label='min mse')
plt.legend()
plt.xlabel('w')
plt.ylabel('mse')
plt.show()

# %%
bs = [b10/10 for b10 in range(-30,80)]
w = 3 #가중치 3으로 가정
x1 = [x[0] for x in xs]
mses = []
for b in bs:
  yp = np.array([w*x+b for x in x1])
  mses.append(mse(yp,nys))
print(mses)
# Out:
# [25.5, 24.543333333333333, 23.60666666666667, 22.689999999999998, 21.793333333333333, 20.916666666666668, 20.06, 19.22333333333334, 18.406666666666666, 17.610000000000003, 16.833333333333332, 16.076666666666664, 15.340000000000003, 14.623333333333333, 13.92666666666667, 13.25, 12.593333333333332, 11.956666666666669, 11.339999999999998, 10.743333333333338, 10.166666666666666, 9.609999999999998, 9.073333333333336, 8.556666666666663, 8.060000000000002, 7.583333333333333, 7.126666666666664, 6.690000000000002, 6.273333333333331, 5.876666666666669, 5.5, 5.143333333333332, 4.8066666666666675, 4.4899999999999975, 4.193333333333336, 3.9166666666666665, 3.6599999999999984, 3.4233333333333342, 3.206666666666665, 3.010000000000002, 2.8333333333333335, 2.6766666666666654, 2.5400000000000005, 2.4233333333333325, 2.3266666666666675, 2.25, 2.193333333333333, 2.1566666666666667, 2.1399999999999997, 2.1433333333333335, 2.1666666666666665, 2.2099999999999995, 2.273333333333333, 2.3566666666666674, 2.4599999999999995, 2.5833333333333335, 2.726666666666667, 2.889999999999999, 3.0733333333333346, 3.276666666666666, 3.5, 3.7433333333333345, 4.006666666666664, 4.290000000000002, 4.593333333333332, 4.916666666666667, 5.260000000000002, 5.62333333333333, 6.006666666666669, 6.4099999999999975, 6.833333333333333, 7.276666666666672, 7.739999999999996, 8.223333333333338, 8.726666666666661, 9.25, 9.793333333333338, 10.356666666666664, 10.940000000000005, 11.543333333333328, 12.166666666666666, 12.810000000000008, 13.473333333333331, 14.156666666666668, 14.859999999999992, 15.583333333333334, 16.32666666666667, 17.09, 17.873333333333335, 18.67666666666666, 19.5, 20.34333333333334, 21.206666666666663, 22.090000000000003, 22.993333333333325, 23.916666666666668, 24.86000000000001, 25.823333333333334, 26.806666666666672, 27.80999999999999, 28.833333333333332, 29.87666666666668, 30.939999999999994, 32.02333333333334, 33.12666666666666, 34.25, 35.393333333333345, 36.556666666666665, 37.74, 38.94333333333332]

# %%
n_mses = np.array(mses)
mi = np.argmin(n_mses)
plt.plot(bs,mses,label='b,mse')
plt.plot(bs[mi], mses[mi],'ro',label='min mse')
plt.legend()
plt.xlabel('b')
plt.ylabel('mse')
plt.show()

# %% [markdown]
# * dmse/dw와 dmse/db

# %%
def gradient(xs,ys,w,b): #가중치 w일 때 dmse/dw와 편향 b일 때 dmse/db(bd)를 구하는 함수
  yp = w*xs+b #예측값
  error = ys-yp #에러값
  wd = -2/len(xs)*sum(error*xs)
  bd = -2/len(xs)*sum(error)
  return wd,bd

# %%
xs2 = np.array(xs).reshape(-1)
print(gradient(xs2,nys,2,2))
print(gradient(xs2,nys,3,2))
print(gradient(xs2,nys,4,2))
# Out:
# (-58.0, -9.333333333333332)
# (-1.0, 0.3333333333333333)
# (56.0, 10.0)

# %%
print(gradient(xs2,nys,3.08,1.8))
# Out:
# (1.6266666666666687, 0.7066666666666672)

# %%
print(gradient(xs2,nys,3.0527,1.8))
# Out:
# (0.07056666666668931, 0.44276666666667036)

# %% [markdown]
# * 경사하강법을 이용해서 기울기가 0에 가까운 w와 b를 찾기

# %%
#(경사*lr)만큼 이동하면서 기울기가 0인 지점을 찾는 함수
def gradient_descent(xs,ys,lr=0.001):
  wbhl = [] #학습 히스토리를 기억하기 위한 빈 목록 생성
  wp = np.random.uniform(-1,1) #초기 w를 -1에서 1사이의 랜덤값으로 지정
  bp = np.random.uniform(-1,1) #초기 b를 -1에서 1사이의 랜덤값으로 지정
  wbhl.append([wp,bp])

  for i in range(1000):
    wd,bd = gradient(xs,ys,wp,bp) #경사를 구함
    wp = wp-(wd*lr) #가중치를 기울기*학습률만큼 빼 줌
    bp = bp-(bd*lr) #가충치를 편향*학습률만큼 빼 줌
    wbhl.append([wp,bp])
  return wp,bp,wbhl

# %%
wp,bp,wbhl = gradient_descent(xs2,nys)
print(wp,bp)
print(gradient(xs2,nys,wp,bp))
# Out:
# 3.265784075538465 0.5366640186221762
# (0.00411115237353421, -0.02409256588382084)

# %%
yp = np.array([wp*x+bp for x in xs2])
print(mse(yp,nys))
# Out:
# 1.80805939735505

# %%
for i,(hwp,hbp) in enumerate(wbhl):
  ypp = np.array([hwp*x+hbp for x in xs2])
  print(f"{i}: WP:{hwp:.2f} bp:{hbp:.2f} mse:{mse(ypp,nys)}")
# Out:
# 0: WP:-0.22 bp:-0.09 mse:368.68526508987105
# 1: WP:-0.01 bp:-0.05 mse:326.9129910974122
# 2: WP:0.18 bp:-0.02 mse:289.89687765378375
# 3: WP:0.36 bp:0.01 mse:257.0953917839231
# 4: WP:0.53 bp:0.04 mse:228.02865906279374
# 5: WP:0.69 bp:0.07 mse:202.27144321779824
# 6: WP:0.84 bp:0.09 mse:179.44692506854616
# 7: WP:0.99 bp:0.12 mse:159.2211897920081
# 8: WP:1.12 bp:0.14 mse:141.29834186364295
# 9: WP:1.25 bp:0.16 mse:125.4161762077696
# 10: WP:1.37 bp:0.18 mse:111.34234222760375
# 11: WP:1.48 bp:0.20 mse:98.87094459604005
# 12: WP:1.58 bp:0.22 mse:87.81953107791968
# 13: WP:1.68 bp:0.24 mse:78.02642331665973
# 14: WP:1.77 bp:0.25 mse:69.34835153557282
# 15: WP:1.86 bp:0.27 mse:61.65835855037097
# 16: WP:1.94 bp:0.28 mse:54.843942429279046
# 17: WP:2.02 bp:0.30 mse:48.805410628514444
# 18: WP:2.10 bp:0.31 mse:43.454421524702155
# 19: WP:2.16 bp:0.32 mse:38.71269200734642
# 20: WP:2.23 bp:0.33 mse:34.51085222388203
# 21: WP:2.29 bp:0.34 mse:30.787430722619973
# 22: WP:2.35 bp:0.35 mse:27.4879551465775
# 23: WP:2.40 bp:0.36 mse:24.56415532165403
# 24: WP:2.45 bp:0.37 mse:21.97325708060646
# 25: WP:2.50 bp:0.38 mse:19.67735649171235
# 26: WP:2.55 bp:0.39 mse:17.642865337301476
# 27: WP:2.59 bp:0.39 mse:15.840019729698065
# 28: WP:2.63 bp:0.40 mse:14.242444675793584
# 29: WP:2.67 bp:0.41 mse:12.826768219980183
# 30: WP:2.70 bp:0.41 mse:11.572279520488669
# 31: WP:2.74 bp:0.42 mse:10.460625856905486
# 32: WP:2.77 bp:0.42 mse:9.47554413619307
# 33: WP:2.80 bp:0.43 mse:8.602622969239135
# 34: WP:2.82 bp:0.43 mse:7.829091837196756
# 35: WP:2.85 bp:0.44 mse:7.143634263191373
# 36: WP:2.87 bp:0.44 mse:6.5362222561610315
# 37: WP:2.90 bp:0.45 mse:5.997969604800528
# 38: WP:2.92 bp:0.45 mse:5.521001875350062
# 39: WP:2.94 bp:0.45 mse:5.098341211341007
# 40: WP:2.96 bp:0.46 mse:4.723804249958732
# 41: WP:2.98 bp:0.46 mse:4.3919116615739355
# 42: WP:3.00 bp:0.46 mse:4.097807989037083
# 43: WP:3.01 bp:0.47 mse:3.8371906140123433
# 44: WP:3.03 bp:0.47 mse:3.6062468111530266
# 45: WP:3.04 bp:0.47 mse:3.4015979692427027
# 46: WP:3.05 bp:0.47 mse:3.220250163276648
# 47: WP:3.07 bp:0.47 mse:3.0595503543699607
# 48: WP:3.08 bp:0.48 mse:2.9171475767123556
# 49: WP:3.09 bp:0.48 mse:2.790958543747917
# 50: WP:3.10 bp:0.48 mse:2.6791371704102223
# 51: WP:3.11 bp:0.48 mse:2.580047565533533
# 52: WP:3.12 bp:0.48 mse:2.4922400993284293
# 53: WP:3.13 bp:0.49 mse:2.4144301957971597
# 54: WP:3.14 bp:0.49 mse:2.3454795398291766
# 55: WP:3.14 bp:0.49 mse:2.284379424043089
# 56: WP:3.15 bp:0.49 mse:2.23023599174502
# 57: WP:3.16 bp:0.49 mse:2.182257160113004
# 58: WP:3.17 bp:0.49 mse:2.1397410322980805
# 59: WP:3.17 bp:0.49 mse:2.1020656289151054
# 60: WP:3.18 bp:0.49 mse:2.0686797886985366
# 61: WP:3.18 bp:0.49 mse:2.0390951052029354
# 62: WP:3.19 bp:0.50 mse:2.01287878158487
# 63: WP:3.19 bp:0.50 mse:1.9896472989341378
# 64: WP:3.20 bp:0.50 mse:1.969060805524182
# 65: WP:3.20 bp:0.50 mse:1.9508181448983863
# 66: WP:3.21 bp:0.50 mse:1.9346524500548201
# 67: WP:3.21 bp:0.50 mse:1.9203272392739195
# 68: WP:3.21 bp:0.50 mse:1.9076329564723566
# 69: WP:3.22 bp:0.50 mse:1.8963839054697285
# 70: WP:3.22 bp:0.50 mse:1.8864155333173824
# 71: WP:3.22 bp:0.50 mse:1.8775820229454618
# 72: WP:3.23 bp:0.50 mse:1.8697541599093854
# 73: WP:3.23 bp:0.50 mse:1.862817442027035
# 74: WP:3.23 bp:0.50 mse:1.8566704042512683
# 75: WP:3.23 bp:0.50 mse:1.8512231342712322
# 76: WP:3.23 bp:0.50 mse:1.8463959571262125
# 77: WP:3.24 bp:0.50 mse:1.8421182695884217
# 78: WP:3.24 bp:0.51 mse:1.838327507262087
# 79: WP:3.24 bp:0.51 mse:1.8349682292878928
# 80: WP:3.24 bp:0.51 mse:1.8319913072623162
# 81: WP:3.24 bp:0.51 mse:1.8293532065060047
# 82: WP:3.25 bp:0.51 mse:1.8270153491664167
# 83: WP:3.25 bp:0.51 mse:1.8249435498371283
# 84: WP:3.25 bp:0.51 mse:1.823107515437135
# 85: WP:3.25 bp:0.51 mse:1.821480402033495
# 86: WP:3.25 bp:0.51 mse:1.8200384221238515
# 87: WP:3.25 bp:0.51 mse:1.8187604966334756
# 88: WP:3.25 bp:0.51 mse:1.8176279465356686
# 89: WP:3.25 bp:0.51 mse:1.8166242195840354
# 90: WP:3.26 bp:0.51 mse:1.8157346481588448
# 91: WP:3.26 bp:0.51 mse:1.8149462346847862
# 92: WP:3.26 bp:0.51 mse:1.8142474614809503
# 93: WP:3.26 bp:0.51 mse:1.8136281222611228
# 94: WP:3.26 bp:0.51 mse:1.813079172819336
# 95: WP:3.26 bp:0.51 mse:1.8125925987162634
# 96: WP:3.26 bp:0.51 mse:1.8121612980307402
# 97: WP:3.26 bp:0.51 mse:1.8117789774611037
# 98: WP:3.26 bp:0.51 mse:1.8114400602563794
# 99: WP:3.26 bp:0.51 mse:1.8111396046303254
# 100: WP:3.26 bp:0.51 mse:1.8108732314648244
# 101: WP:3.26 bp:0.51 mse:1.8106370602448925
# 102: WP:3.26 bp:0.51 mse:1.8104276522880942
# 103: WP:3.26 bp:0.51 mse:1.810241960437801
# 104: WP:3.26 bp:0.51 mse:1.81007728448437
# 105: WP:3.26 bp:0.51 mse:1.809931231661986
# 106: WP:3.26 bp:0.51 mse:1.8098016816433498
# 107: WP:3.26 bp:0.51 mse:1.8096867555200227
# 108: WP:3.26 bp:0.51 mse:1.8095847883146423
# 109: WP:3.27 bp:0.51 mse:1.8094943046229064
# 110: WP:3.27 bp:0.51 mse:1.8094139970288932
# 111: WP:3.27 bp:0.51 mse:1.8093427069780585
# 112: WP:3.27 bp:0.51 mse:1.8092794078279637
# 113: WP:3.27 bp:0.51 mse:1.8092231898288735
# 114: WP:3.27 bp:0.51 mse:1.809173246814426
# 115: WP:3.27 bp:0.51 mse:1.8091288644077188
# 116: WP:3.27 bp:0.51 mse:1.8090894095702152
# 117: WP:3.27 bp:0.51 mse:1.809054321340632
# 118: WP:3.27 bp:0.51 mse:1.809023102628257
# 119: WP:3.27 bp:0.51 mse:1.808995312940709
# 120: WP:3.27 bp:0.51 mse:1.8089705619396854
# 121: WP:3.27 bp:0.51 mse:1.808948503730458
# 122: WP:3.27 bp:0.51 mse:1.8089288318015537
# 123: WP:3.27 bp:0.51 mse:1.8089112745406155
# 124: WP:3.27 bp:0.51 mse:1.8088955912608133
# 125: WP:3.27 bp:0.51 mse:1.8088815686796735
# 126: WP:3.27 bp:0.51 mse:1.8088690177988518
# 127: WP:3.27 bp:0.51 mse:1.8088577711391622
# 128: WP:3.27 bp:0.51 mse:1.8088476802904088
# 129: WP:3.27 bp:0.51 mse:1.808838613740208
# 130: WP:3.27 bp:0.51 mse:1.8088304549500345
# 131: WP:3.27 bp:0.51 mse:1.808823100650275
# 132: WP:3.27 bp:0.51 mse:1.8088164593294673
# 133: WP:3.27 bp:0.51 mse:1.8088104498955164
# 134: WP:3.27 bp:0.51 mse:1.8088050004893514
# 135: WP:3.27 bp:0.51 mse:1.8088000474336638
# 136: WP:3.27 bp:0.51 mse:1.8087955343013313
# 137: WP:3.27 bp:0.51 mse:1.808791411089928
# 138: WP:3.27 bp:0.51 mse:1.8087876334902029
# 139: WP:3.27 bp:0.51 mse:1.8087841622378615
# 140: WP:3.27 bp:0.51 mse:1.8087809625391575
# 141: WP:3.27 bp:0.51 mse:1.808778003561873
# 142: WP:3.27 bp:0.51 mse:1.808775257984258
# 143: WP:3.27 bp:0.51 mse:1.8087727015953445
# 144: WP:3.27 bp:0.51 mse:1.8087703129407409
# 145: WP:3.27 bp:0.51 mse:1.808768073008778
# 146: WP:3.27 bp:0.51 mse:1.8087659649523828
# 147: WP:3.27 bp:0.51 mse:1.8087639738426124
# 148: WP:3.27 bp:0.51 mse:1.8087620864502716
# 149: WP:3.27 bp:0.51 mse:1.808760291052358
# 150: WP:3.27 bp:0.51 mse:1.808758577260594
# 151: WP:3.27 bp:0.51 mse:1.8087569358694326
# 152: WP:3.27 bp:0.51 mse:1.8087553587214114
# 153: WP:3.27 bp:0.51 mse:1.8087538385878048
# 154: WP:3.27 bp:0.51 mse:1.8087523690628895
# 155: WP:3.27 bp:0.51 mse:1.8087509444702314
# 156: WP:3.27 bp:0.51 mse:1.8087495597796466
# 157: WP:3.27 bp:0.51 mse:1.8087482105336283
# 158: WP:3.27 bp:0.51 mse:1.80874689278214
# 159: WP:3.27 bp:0.51 mse:1.8087456030248266
# 160: WP:3.27 bp:0.51 mse:1.8087443381598283
# 161: WP:3.27 bp:0.51 mse:1.8087430954383965
# 162: WP:3.27 bp:0.51 mse:1.8087418724246935
# 163: WP:3.27 bp:0.51 mse:1.8087406669601662
# 164: WP:3.27 bp:0.51 mse:1.808739477131974
# 165: WP:3.27 bp:0.51 mse:1.8087383012450031
# 166: WP:3.27 bp:0.51 mse:1.8087371377970973
# 167: WP:3.27 bp:0.51 mse:1.808735985457065
# 168: WP:3.27 bp:0.51 mse:1.8087348430452257
# 169: WP:3.27 bp:0.51 mse:1.8087337095161606
# 170: WP:3.27 bp:0.51 mse:1.8087325839434165
# 171: WP:3.27 bp:0.51 mse:1.8087314655059707
# 172: WP:3.27 bp:0.51 mse:1.8087303534762196
# 173: WP:3.27 bp:0.51 mse:1.808729247209346
# 174: WP:3.27 bp:0.51 mse:1.8087281461338893
# 175: WP:3.27 bp:0.51 mse:1.808727049743399
# 176: WP:3.27 bp:0.51 mse:1.808725957589023
# 177: WP:3.27 bp:0.51 mse:1.8087248692729647
# 178: WP:3.27 bp:0.51 mse:1.8087237844426536
# 179: WP:3.27 bp:0.51 mse:1.8087227027856099
# 180: WP:3.27 bp:0.51 mse:1.8087216240248682
# 181: WP:3.27 bp:0.51 mse:1.808720547914939
# 182: WP:3.27 bp:0.51 mse:1.8087194742382307
# 183: WP:3.27 bp:0.51 mse:1.808718402801862
# 184: WP:3.27 bp:0.51 mse:1.808717333434857
# 185: WP:3.27 bp:0.51 mse:1.8087162659856422
# 186: WP:3.27 bp:0.51 mse:1.808715200319852
# 187: WP:3.27 bp:0.51 mse:1.808714136318356
# 188: WP:3.27 bp:0.51 mse:1.808713073875528
# 189: WP:3.27 bp:0.51 mse:1.8087120128977119
# 190: WP:3.27 bp:0.51 mse:1.8087109533018568
# 191: WP:3.27 bp:0.51 mse:1.808709895014304
# 192: WP:3.27 bp:0.51 mse:1.8087088379697327
# 193: WP:3.27 bp:0.51 mse:1.8087077821101891
# 194: WP:3.27 bp:0.51 mse:1.8087067273842707
# 195: WP:3.27 bp:0.51 mse:1.8087056737463587
# 196: WP:3.27 bp:0.51 mse:1.8087046211559794
# 197: WP:3.27 bp:0.51 mse:1.8087035695772034
# 198: WP:3.27 bp:0.51 mse:1.8087025189781334
# 199: WP:3.27 bp:0.51 mse:1.8087014693304477
# 200: WP:3.27 bp:0.51 mse:1.8087004206089914
# 201: WP:3.27 bp:0.51 mse:1.8086993727914127
# 202: WP:3.27 bp:0.51 mse:1.8086983258578504
# 203: WP:3.27 bp:0.51 mse:1.808697279790641
# 204: WP:3.27 bp:0.51 mse:1.808696234574082
# 205: WP:3.27 bp:0.51 mse:1.8086951901941932
# 206: WP:3.27 bp:0.51 mse:1.8086941466385307
# 207: WP:3.27 bp:0.51 mse:1.8086931038960081
# 208: WP:3.27 bp:0.51 mse:1.808692061956747
# 209: WP:3.27 bp:0.51 mse:1.808691020811933
# 210: WP:3.27 bp:0.51 mse:1.8086899804536969
# 211: WP:3.27 bp:0.51 mse:1.8086889408750109
# 212: WP:3.27 bp:0.51 mse:1.8086879020695836
# 213: WP:3.27 bp:0.51 mse:1.80868686403179
# 214: WP:3.27 bp:0.51 mse:1.808685826756581
# 215: WP:3.27 bp:0.51 mse:1.808684790239426
# 216: WP:3.27 bp:0.51 mse:1.8086837544762568
# 217: WP:3.27 bp:0.51 mse:1.8086827194634072
# 218: WP:3.27 bp:0.51 mse:1.8086816851975671
# 219: WP:3.27 bp:0.52 mse:1.808680651675756
# 220: WP:3.27 bp:0.52 mse:1.8086796188952672
# 221: WP:3.27 bp:0.52 mse:1.8086785868536452
# 222: WP:3.27 bp:0.52 mse:1.8086775555486587
# 223: WP:3.27 bp:0.52 mse:1.8086765249782737
# 224: WP:3.27 bp:0.52 mse:1.808675495140629
# 225: WP:3.27 bp:0.52 mse:1.8086744660340182
# 226: WP:3.27 bp:0.52 mse:1.808673437656873
# 227: WP:3.27 bp:0.52 mse:1.8086724100077438
# 228: WP:3.27 bp:0.52 mse:1.808671383085288
# 229: WP:3.27 bp:0.52 mse:1.8086703568882683
# 230: WP:3.27 bp:0.52 mse:1.8086693314155182
# 231: WP:3.27 bp:0.52 mse:1.808668306665955
# 232: WP:3.27 bp:0.52 mse:1.8086672826385595
# 233: WP:3.27 bp:0.52 mse:1.8086662593323728
# 234: WP:3.27 bp:0.52 mse:1.8086652367464862
# 235: WP:3.27 bp:0.52 mse:1.8086642148800405
# 236: WP:3.27 bp:0.52 mse:1.8086631937322146
# 237: WP:3.27 bp:0.52 mse:1.808662173302226
# 238: WP:3.27 bp:0.52 mse:1.808661153589326
# 239: WP:3.27 bp:0.52 mse:1.8086601345927875
# 240: WP:3.27 bp:0.52 mse:1.808659116311916
# 241: WP:3.27 bp:0.52 mse:1.8086580987460386
# 242: WP:3.27 bp:0.52 mse:1.8086570818945005
# 243: WP:3.27 bp:0.52 mse:1.808656065756668
# 244: WP:3.27 bp:0.52 mse:1.8086550503319163
# 245: WP:3.27 bp:0.52 mse:1.8086540356196454
# 246: WP:3.27 bp:0.52 mse:1.8086530216192542
# 247: WP:3.27 bp:0.52 mse:1.808652008330168
# 248: WP:3.27 bp:0.52 mse:1.808650995751809
# 249: WP:3.27 bp:0.52 mse:1.8086499838836139
# 250: WP:3.27 bp:0.52 mse:1.80864897272503
# 251: WP:3.27 bp:0.52 mse:1.8086479622755058
# 252: WP:3.27 bp:0.52 mse:1.8086469525344995
# 253: WP:3.27 bp:0.52 mse:1.8086459435014755
# 254: WP:3.27 bp:0.52 mse:1.8086449351759015
# 255: WP:3.27 bp:0.52 mse:1.8086439275572468
# 256: WP:3.27 bp:0.52 mse:1.80864292064499
# 257: WP:3.27 bp:0.52 mse:1.8086419144386114
# 258: WP:3.27 bp:0.52 mse:1.8086409089375959
# 259: WP:3.27 bp:0.52 mse:1.808639904141426
# 260: WP:3.27 bp:0.52 mse:1.8086389000495933
# 261: WP:3.27 bp:0.52 mse:1.8086378966615857
# 262: WP:3.27 bp:0.52 mse:1.8086368939769006
# 263: WP:3.27 bp:0.52 mse:1.8086358919950278
# 264: WP:3.27 bp:0.52 mse:1.8086348907154708
# 265: WP:3.27 bp:0.52 mse:1.8086338901377204
# 266: WP:3.27 bp:0.52 mse:1.8086328902612792
# 267: WP:3.27 bp:0.52 mse:1.808631891085651
# 268: WP:3.27 bp:0.52 mse:1.8086308926103367
# 269: WP:3.27 bp:0.52 mse:1.8086298948348374
# 270: WP:3.27 bp:0.52 mse:1.8086288977586593
# 271: WP:3.27 bp:0.52 mse:1.808627901381308
# 272: WP:3.27 bp:0.52 mse:1.8086269057022892
# 273: WP:3.27 bp:0.52 mse:1.8086259107211076
# 274: WP:3.27 bp:0.52 mse:1.8086249164372756
# 275: WP:3.27 bp:0.52 mse:1.8086239228502985
# 276: WP:3.27 bp:0.52 mse:1.8086229299596868
# 277: WP:3.27 bp:0.52 mse:1.808621937764946
# 278: WP:3.27 bp:0.52 mse:1.8086209462655933
# 279: WP:3.27 bp:0.52 mse:1.8086199554611369
# 280: WP:3.27 bp:0.52 mse:1.8086189653510847
# 281: WP:3.27 bp:0.52 mse:1.8086179759349525
# 282: WP:3.27 bp:0.52 mse:1.8086169872122528
# 283: WP:3.27 bp:0.52 mse:1.808615999182497
# 284: WP:3.27 bp:0.52 mse:1.8086150118451971
# 285: WP:3.27 bp:0.52 mse:1.8086140251998726
# 286: WP:3.27 bp:0.52 mse:1.8086130392460313
# 287: WP:3.27 bp:0.52 mse:1.8086120539831902
# 288: WP:3.27 bp:0.52 mse:1.8086110694108666
# 289: WP:3.27 bp:0.52 mse:1.8086100855285734
# 290: WP:3.27 bp:0.52 mse:1.8086091023358286
# 291: WP:3.27 bp:0.52 mse:1.8086081198321462
# 292: WP:3.27 bp:0.52 mse:1.808607138017044
# 293: WP:3.27 bp:0.52 mse:1.80860615689004
# 294: WP:3.27 bp:0.52 mse:1.8086051764506526
# 295: WP:3.27 bp:0.52 mse:1.808604196698397
# 296: WP:3.27 bp:0.52 mse:1.8086032176327913
# 297: WP:3.27 bp:0.52 mse:1.8086022392533552
# 298: WP:3.27 bp:0.52 mse:1.8086012615596065
# 299: WP:3.27 bp:0.52 mse:1.8086002845510674
# 300: WP:3.27 bp:0.52 mse:1.8085993082272545
# 301: WP:3.27 bp:0.52 mse:1.8085983325876889
# 302: WP:3.27 bp:0.52 mse:1.8085973576318912
# 303: WP:3.27 bp:0.52 mse:1.8085963833593823
# 304: WP:3.27 bp:0.52 mse:1.8085954097696824
# 305: WP:3.27 bp:0.52 mse:1.8085944368623148
# 306: WP:3.27 bp:0.52 mse:1.8085934646367976
# 307: WP:3.27 bp:0.52 mse:1.8085924930926562
# 308: WP:3.27 bp:0.52 mse:1.8085915222294122
# 309: WP:3.27 bp:0.52 mse:1.8085905520465893
# 310: WP:3.27 bp:0.52 mse:1.808589582543707
# 311: WP:3.27 bp:0.52 mse:1.8085886137202902
# 312: WP:3.27 bp:0.52 mse:1.8085876455758665
# 313: WP:3.27 bp:0.52 mse:1.8085866781099549
# 314: WP:3.27 bp:0.52 mse:1.8085857113220811
# 315: WP:3.27 bp:0.52 mse:1.8085847452117738
# 316: WP:3.27 bp:0.52 mse:1.8085837797785531
# 317: WP:3.27 bp:0.52 mse:1.808582815021946
# 318: WP:3.27 bp:0.52 mse:1.8085818509414793
# 319: WP:3.27 bp:0.52 mse:1.8085808875366771
# 320: WP:3.27 bp:0.52 mse:1.8085799248070697
# 321: WP:3.27 bp:0.52 mse:1.8085789627521807
# 322: WP:3.27 bp:0.52 mse:1.8085780013715373
# 323: WP:3.27 bp:0.52 mse:1.8085770406646662
# 324: WP:3.27 bp:0.52 mse:1.8085760806310984
# 325: WP:3.27 bp:0.52 mse:1.808575121270361
# 326: WP:3.27 bp:0.52 mse:1.8085741625819807
# 327: WP:3.27 bp:0.52 mse:1.808573204565488
# 328: WP:3.27 bp:0.52 mse:1.8085722472204104
# 329: WP:3.27 bp:0.52 mse:1.8085712905462785
# 330: WP:3.27 bp:0.52 mse:1.8085703345426216
# 331: WP:3.27 bp:0.52 mse:1.808569379208971
# 332: WP:3.27 bp:0.52 mse:1.8085684245448548
# 333: WP:3.27 bp:0.52 mse:1.8085674705498036
# 334: WP:3.27 bp:0.52 mse:1.8085665172233536
# 335: WP:3.27 bp:0.52 mse:1.8085655645650307
# 336: WP:3.27 bp:0.52 mse:1.808564612574367
# 337: WP:3.27 bp:0.52 mse:1.808563661250899
# 338: WP:3.27 bp:0.52 mse:1.808562710594155
# 339: WP:3.27 bp:0.52 mse:1.8085617606036666
# 340: WP:3.27 bp:0.52 mse:1.808560811278972
# 341: WP:3.27 bp:0.52 mse:1.808559862619601
# 342: WP:3.27 bp:0.52 mse:1.808558914625089
# 343: WP:3.27 bp:0.52 mse:1.8085579672949674
# 344: WP:3.27 bp:0.52 mse:1.8085570206287747
# 345: WP:3.27 bp:0.52 mse:1.8085560746260396
# 346: WP:3.27 bp:0.52 mse:1.8085551292863038
# 347: WP:3.27 bp:0.52 mse:1.8085541846090976
# 348: WP:3.27 bp:0.52 mse:1.8085532405939595
# 349: WP:3.27 bp:0.52 mse:1.8085522972404255
# 350: WP:3.27 bp:0.52 mse:1.8085513545480314
# 351: WP:3.27 bp:0.52 mse:1.8085504125163119
# 352: WP:3.27 bp:0.52 mse:1.8085494711448058
# 353: WP:3.27 bp:0.52 mse:1.8085485304330486
# 354: WP:3.27 bp:0.52 mse:1.8085475903805819
# 355: WP:3.27 bp:0.52 mse:1.8085466509869421
# 356: WP:3.27 bp:0.52 mse:1.8085457122516628
# 357: WP:3.27 bp:0.52 mse:1.8085447741742906
# 358: WP:3.27 bp:0.52 mse:1.8085438367543574
# 359: WP:3.27 bp:0.52 mse:1.8085428999914066
# 360: WP:3.27 bp:0.52 mse:1.8085419638849762
# 361: WP:3.27 bp:0.52 mse:1.808541028434606
# 362: WP:3.27 bp:0.52 mse:1.8085400936398344
# 363: WP:3.27 bp:0.52 mse:1.8085391595002067
# 364: WP:3.27 bp:0.52 mse:1.80853822601526
# 365: WP:3.27 bp:0.52 mse:1.8085372931845376
# 366: WP:3.27 bp:0.52 mse:1.8085363610075798
# 367: WP:3.27 bp:0.52 mse:1.8085354294839282
# 368: WP:3.27 bp:0.52 mse:1.8085344986131233
# 369: WP:3.27 bp:0.52 mse:1.8085335683947112
# 370: WP:3.27 bp:0.52 mse:1.8085326388282346
# 371: WP:3.27 bp:0.52 mse:1.8085317099132332
# 372: WP:3.27 bp:0.52 mse:1.8085307816492522
# 373: WP:3.27 bp:0.52 mse:1.8085298540358352
# 374: WP:3.27 bp:0.52 mse:1.8085289270725282
# 375: WP:3.27 bp:0.52 mse:1.8085280007588727
# 376: WP:3.27 bp:0.52 mse:1.8085270750944147
# 377: WP:3.27 bp:0.52 mse:1.8085261500786984
# 378: WP:3.27 bp:0.52 mse:1.8085252257112698
# 379: WP:3.27 bp:0.52 mse:1.8085243019916752
# 380: WP:3.27 bp:0.52 mse:1.8085233789194586
# 381: WP:3.27 bp:0.52 mse:1.8085224564941702
# 382: WP:3.27 bp:0.52 mse:1.8085215347153512
# 383: WP:3.27 bp:0.52 mse:1.8085206135825522
# 384: WP:3.27 bp:0.52 mse:1.808519693095322
# 385: WP:3.27 bp:0.52 mse:1.8085187732532015
# 386: WP:3.27 bp:0.52 mse:1.808517854055747
# 387: WP:3.27 bp:0.52 mse:1.8085169355024984
# 388: WP:3.27 bp:0.52 mse:1.80851601759301
# 389: WP:3.27 bp:0.52 mse:1.8085151003268312
# 390: WP:3.27 bp:0.52 mse:1.8085141837035066
# 391: WP:3.27 bp:0.52 mse:1.8085132677225886
# 392: WP:3.27 bp:0.52 mse:1.8085123523836264
# 393: WP:3.27 bp:0.52 mse:1.8085114376861677
# 394: WP:3.27 bp:0.52 mse:1.8085105236297683
# 395: WP:3.27 bp:0.52 mse:1.8085096102139737
# 396: WP:3.27 bp:0.52 mse:1.8085086974383386
# 397: WP:3.27 bp:0.52 mse:1.8085077853024114
# 398: WP:3.27 bp:0.52 mse:1.8085068738057462
# 399: WP:3.27 bp:0.52 mse:1.8085059629478941
# 400: WP:3.27 bp:0.52 mse:1.808505052728407
# 401: WP:3.27 bp:0.52 mse:1.8085041431468383
# 402: WP:3.27 bp:0.52 mse:1.8085032342027392
# 403: WP:3.27 bp:0.52 mse:1.8085023258956656
# 404: WP:3.27 bp:0.52 mse:1.8085014182251706
# 405: WP:3.27 bp:0.52 mse:1.8085005111908032
# 406: WP:3.27 bp:0.52 mse:1.808499604792125
# 407: WP:3.27 bp:0.52 mse:1.8084986990286842
# 408: WP:3.27 bp:0.52 mse:1.8084977939000397
# 409: WP:3.27 bp:0.52 mse:1.8084968894057472
# 410: WP:3.27 bp:0.52 mse:1.8084959855453564
# 411: WP:3.27 bp:0.52 mse:1.80849508231843
# 412: WP:3.27 bp:0.52 mse:1.8084941797245184
# 413: WP:3.27 bp:0.52 mse:1.808493277763179
# 414: WP:3.27 bp:0.52 mse:1.8084923764339742
# 415: WP:3.27 bp:0.52 mse:1.8084914757364545
# 416: WP:3.27 bp:0.52 mse:1.808490575670179
# 417: WP:3.27 bp:0.52 mse:1.8084896762347065
# 418: WP:3.27 bp:0.52 mse:1.808488777429594
# 419: WP:3.27 bp:0.52 mse:1.8084878792543977
# 420: WP:3.27 bp:0.52 mse:1.8084869817086802
# 421: WP:3.27 bp:0.52 mse:1.808486084791997
# 422: WP:3.27 bp:0.52 mse:1.8084851885039102
# 423: WP:3.27 bp:0.52 mse:1.8084842928439755
# 424: WP:3.27 bp:0.52 mse:1.8084833978117558
# 425: WP:3.27 bp:0.52 mse:1.8084825034068108
# 426: WP:3.27 bp:0.52 mse:1.8084816096286989
# 427: WP:3.27 bp:0.52 mse:1.8084807164769847
# 428: WP:3.27 bp:0.52 mse:1.808479823951225
# 429: WP:3.27 bp:0.52 mse:1.8084789320509815
# 430: WP:3.27 bp:0.52 mse:1.8084780407758194
# 431: WP:3.27 bp:0.52 mse:1.8084771501252968
# 432: WP:3.27 bp:0.52 mse:1.8084762600989757
# 433: WP:3.27 bp:0.52 mse:1.8084753706964223
# 434: WP:3.27 bp:0.52 mse:1.8084744819171987
# 435: WP:3.27 bp:0.52 mse:1.808473593760865
# 436: WP:3.27 bp:0.52 mse:1.8084727062269874
# 437: WP:3.27 bp:0.52 mse:1.8084718193151275
# 438: WP:3.27 bp:0.52 mse:1.8084709330248507
# 439: WP:3.27 bp:0.52 mse:1.8084700473557216
# 440: WP:3.27 bp:0.52 mse:1.808469162307306
# 441: WP:3.27 bp:0.52 mse:1.8084682778791665
# 442: WP:3.27 bp:0.52 mse:1.8084673940708675
# 443: WP:3.27 bp:0.52 mse:1.8084665108819789
# 444: WP:3.27 bp:0.52 mse:1.808465628312063
# 445: WP:3.27 bp:0.52 mse:1.8084647463606878
# 446: WP:3.27 bp:0.52 mse:1.8084638650274185
# 447: WP:3.27 bp:0.52 mse:1.8084629843118212
# 448: WP:3.27 bp:0.52 mse:1.8084621042134665
# 449: WP:3.27 bp:0.52 mse:1.808461224731918
# 450: WP:3.27 bp:0.52 mse:1.8084603458667459
# 451: WP:3.27 bp:0.52 mse:1.8084594676175172
# 452: WP:3.27 bp:0.52 mse:1.8084585899837993
# 453: WP:3.27 bp:0.52 mse:1.8084577129651611
# 454: WP:3.27 bp:0.52 mse:1.808456836561174
# 455: WP:3.27 bp:0.52 mse:1.808455960771407
# 456: WP:3.27 bp:0.52 mse:1.8084550855954256
# 457: WP:3.27 bp:0.52 mse:1.8084542110328048
# 458: WP:3.27 bp:0.52 mse:1.8084533370831082
# 459: WP:3.27 bp:0.52 mse:1.8084524637459136
# 460: WP:3.27 bp:0.52 mse:1.8084515910207875
# 461: WP:3.27 bp:0.52 mse:1.8084507189073025
# 462: WP:3.27 bp:0.52 mse:1.8084498474050281
# 463: WP:3.27 bp:0.52 mse:1.8084489765135372
# 464: WP:3.27 bp:0.52 mse:1.808448106232401
# 465: WP:3.27 bp:0.52 mse:1.8084472365611912
# 466: WP:3.27 bp:0.52 mse:1.8084463674994842
# 467: WP:3.27 bp:0.52 mse:1.808445499046849
# 468: WP:3.27 bp:0.52 mse:1.8084446312028597
# 469: WP:3.27 bp:0.52 mse:1.808443763967091
# 470: WP:3.27 bp:0.52 mse:1.808442897339112
# 471: WP:3.27 bp:0.52 mse:1.8084420313185048
# 472: WP:3.27 bp:0.52 mse:1.8084411659048356
# 473: WP:3.27 bp:0.52 mse:1.8084403010976828
# 474: WP:3.27 bp:0.52 mse:1.8084394368966235
# 475: WP:3.27 bp:0.52 mse:1.8084385733012311
# 476: WP:3.27 bp:0.52 mse:1.8084377103110771
# 477: WP:3.27 bp:0.52 mse:1.808436847925744
# 478: WP:3.27 bp:0.52 mse:1.808435986144801
# 479: WP:3.27 bp:0.52 mse:1.8084351249678319
# 480: WP:3.27 bp:0.52 mse:1.8084342643944087
# 481: WP:3.27 bp:0.52 mse:1.8084334044241077
# 482: WP:3.27 bp:0.52 mse:1.808432545056509
# 483: WP:3.27 bp:0.52 mse:1.8084316862911909
# 484: WP:3.27 bp:0.52 mse:1.8084308281277286
# 485: WP:3.27 bp:0.52 mse:1.8084299705657003
# 486: WP:3.27 bp:0.52 mse:1.808429113604686
# 487: WP:3.27 bp:0.52 mse:1.808428257244264
# 488: WP:3.27 bp:0.52 mse:1.8084274014840132
# 489: WP:3.27 bp:0.52 mse:1.8084265463235116
# 490: WP:3.27 bp:0.52 mse:1.808425691762343
# 491: WP:3.27 bp:0.52 mse:1.8084248378000822
# 492: WP:3.27 bp:0.52 mse:1.8084239844363141
# 493: WP:3.27 bp:0.52 mse:1.8084231316706176
# 494: WP:3.27 bp:0.52 mse:1.8084222795025717
# 495: WP:3.27 bp:0.52 mse:1.8084214279317583
# 496: WP:3.27 bp:0.52 mse:1.8084205769577617
# 497: WP:3.27 bp:0.52 mse:1.8084197265801591
# 498: WP:3.27 bp:0.52 mse:1.8084188767985354
# 499: WP:3.27 bp:0.52 mse:1.808418027612472
# 500: WP:3.27 bp:0.52 mse:1.8084171790215537
# 501: WP:3.27 bp:0.52 mse:1.808416331025361
# 502: WP:3.27 bp:0.52 mse:1.808415483623475
# 503: WP:3.27 bp:0.52 mse:1.808414636815483
# 504: WP:3.27 bp:0.52 mse:1.8084137906009703
# 505: WP:3.27 bp:0.52 mse:1.808412944979515
# 506: WP:3.27 bp:0.52 mse:1.8084120999507085
# 507: WP:3.27 bp:0.52 mse:1.8084112555141287
# 508: WP:3.27 bp:0.52 mse:1.8084104116693647
# 509: WP:3.27 bp:0.52 mse:1.8084095684159998
# 510: WP:3.27 bp:0.52 mse:1.8084087257536199
# 511: WP:3.27 bp:0.52 mse:1.8084078836818123
# 512: WP:3.27 bp:0.52 mse:1.8084070422001604
# 513: WP:3.27 bp:0.52 mse:1.8084062013082531
# 514: WP:3.27 bp:0.52 mse:1.8084053610056758
# 515: WP:3.27 bp:0.52 mse:1.8084045212920177
# 516: WP:3.27 bp:0.52 mse:1.8084036821668628
# 517: WP:3.27 bp:0.52 mse:1.8084028436297983
# 518: WP:3.27 bp:0.52 mse:1.8084020056804169
# 519: WP:3.27 bp:0.52 mse:1.808401168318303
# 520: WP:3.27 bp:0.52 mse:1.8084003315430424
# 521: WP:3.27 bp:0.52 mse:1.808399495354231
# 522: WP:3.27 bp:0.52 mse:1.808398659751451
# 523: WP:3.27 bp:0.52 mse:1.8083978247342978
# 524: WP:3.27 bp:0.52 mse:1.8083969903023551
# 525: WP:3.27 bp:0.52 mse:1.808396156455216
# 526: WP:3.27 bp:0.52 mse:1.80839532319247
# 527: WP:3.27 bp:0.52 mse:1.8083944905137086
# 528: WP:3.27 bp:0.52 mse:1.8083936584185205
# 529: WP:3.27 bp:0.52 mse:1.8083928269064986
# 530: WP:3.27 bp:0.52 mse:1.80839199597723
# 531: WP:3.27 bp:0.52 mse:1.8083911656303124
# 532: WP:3.27 bp:0.52 mse:1.8083903358653342
# 533: WP:3.27 bp:0.52 mse:1.8083895066818894
# 534: WP:3.27 bp:0.52 mse:1.8083886780795684
# 535: WP:3.27 bp:0.52 mse:1.808387850057966
# 536: WP:3.27 bp:0.52 mse:1.808387022616672
# 537: WP:3.27 bp:0.52 mse:1.808386195755281
# 538: WP:3.27 bp:0.52 mse:1.8083853694733882
# 539: WP:3.27 bp:0.52 mse:1.8083845437705877
# 540: WP:3.27 bp:0.52 mse:1.8083837186464697
# 541: WP:3.27 bp:0.52 mse:1.808382894100635
# 542: WP:3.27 bp:0.52 mse:1.8083820701326732
# 543: WP:3.27 bp:0.52 mse:1.80838124674218
# 544: WP:3.27 bp:0.52 mse:1.8083804239287506
# 545: WP:3.27 bp:0.52 mse:1.8083796016919826
# 546: WP:3.27 bp:0.52 mse:1.8083787800314708
# 547: WP:3.27 bp:0.52 mse:1.8083779589468116
# 548: WP:3.27 bp:0.52 mse:1.8083771384376022
# 549: WP:3.27 bp:0.52 mse:1.8083763185034352
# 550: WP:3.27 bp:0.52 mse:1.8083754991439116
# 551: WP:3.27 bp:0.52 mse:1.8083746803586285
# 552: WP:3.27 bp:0.52 mse:1.8083738621471825
# 553: WP:3.27 bp:0.53 mse:1.8083730445091728
# 554: WP:3.27 bp:0.53 mse:1.8083722274441918
# 555: WP:3.27 bp:0.53 mse:1.8083714109518454
# 556: WP:3.27 bp:0.53 mse:1.8083705950317313
# 557: WP:3.27 bp:0.53 mse:1.8083697796834421
# 558: WP:3.27 bp:0.53 mse:1.8083689649065835
# 559: WP:3.27 bp:0.53 mse:1.808368150700753
# 560: WP:3.27 bp:0.53 mse:1.8083673370655495
# 561: WP:3.27 bp:0.53 mse:1.808366524000574
# 562: WP:3.27 bp:0.53 mse:1.8083657115054275
# 563: WP:3.27 bp:0.53 mse:1.8083648995797088
# 564: WP:3.27 bp:0.53 mse:1.8083640882230176
# 565: WP:3.27 bp:0.53 mse:1.8083632774349614
# 566: WP:3.27 bp:0.53 mse:1.8083624672151348
# 567: WP:3.27 bp:0.53 mse:1.8083616575631443
# 568: WP:3.27 bp:0.53 mse:1.8083608484785898
# 569: WP:3.27 bp:0.53 mse:1.808360039961073
# 570: WP:3.27 bp:0.53 mse:1.8083592320101955
# 571: WP:3.27 bp:0.53 mse:1.8083584246255657
# 572: WP:3.27 bp:0.53 mse:1.8083576178067797
# 573: WP:3.27 bp:0.53 mse:1.8083568115534472
# 574: WP:3.27 bp:0.53 mse:1.808356005865166
# 575: WP:3.27 bp:0.53 mse:1.8083552007415464
# 576: WP:3.27 bp:0.53 mse:1.808354396182188
# 577: WP:3.27 bp:0.53 mse:1.8083535921866962
# 578: WP:3.27 bp:0.53 mse:1.808352788754675
# 579: WP:3.27 bp:0.53 mse:1.8083519858857333
# 580: WP:3.27 bp:0.53 mse:1.8083511835794717
# 581: WP:3.27 bp:0.53 mse:1.808350381835499
# 582: WP:3.27 bp:0.53 mse:1.8083495806534218
# 583: WP:3.27 bp:0.53 mse:1.8083487800328435
# 584: WP:3.27 bp:0.53 mse:1.8083479799733722
# 585: WP:3.27 bp:0.53 mse:1.8083471804746116
# 586: WP:3.27 bp:0.53 mse:1.8083463815361762
# 587: WP:3.27 bp:0.53 mse:1.8083455831576654
# 588: WP:3.27 bp:0.53 mse:1.8083447853386891
# 589: WP:3.27 bp:0.53 mse:1.8083439880788592
# 590: WP:3.27 bp:0.53 mse:1.808343191377779
# 591: WP:3.27 bp:0.53 mse:1.808342395235058
# 592: WP:3.27 bp:0.53 mse:1.8083415996503056
# 593: WP:3.27 bp:0.53 mse:1.8083408046231304
# 594: WP:3.27 bp:0.53 mse:1.8083400101531424
# 595: WP:3.27 bp:0.53 mse:1.8083392162399454
# 596: WP:3.27 bp:0.53 mse:1.8083384228831607
# 597: WP:3.27 bp:0.53 mse:1.8083376300823903
# 598: WP:3.27 bp:0.53 mse:1.8083368378372473
# 599: WP:3.27 bp:0.53 mse:1.8083360461473375
# 600: WP:3.27 bp:0.53 mse:1.80833525501228
# 601: WP:3.27 bp:0.53 mse:1.808334464431676
# 602: WP:3.27 bp:0.53 mse:1.8083336744051473
# 603: WP:3.27 bp:0.53 mse:1.8083328849322966
# 604: WP:3.27 bp:0.53 mse:1.8083320960127418
# 605: WP:3.27 bp:0.53 mse:1.8083313076460927
# 606: WP:3.27 bp:0.53 mse:1.8083305198319606
# 607: WP:3.27 bp:0.53 mse:1.8083297325699625
# 608: WP:3.27 bp:0.53 mse:1.8083289458597067
# 609: WP:3.27 bp:0.53 mse:1.8083281597008085
# 610: WP:3.27 bp:0.53 mse:1.8083273740928851
# 611: WP:3.27 bp:0.53 mse:1.8083265890355433
# 612: WP:3.27 bp:0.53 mse:1.8083258045284014
# 613: WP:3.27 bp:0.53 mse:1.808325020571074
# 614: WP:3.27 bp:0.53 mse:1.8083242371631751
# 615: WP:3.27 bp:0.53 mse:1.8083234543043185
# 616: WP:3.27 bp:0.53 mse:1.8083226719941206
# 617: WP:3.27 bp:0.53 mse:1.808321890232195
# 618: WP:3.27 bp:0.53 mse:1.808321109018163
# 619: WP:3.27 bp:0.53 mse:1.8083203283516338
# 620: WP:3.27 bp:0.53 mse:1.8083195482322292
# 621: WP:3.27 bp:0.53 mse:1.8083187686595625
# 622: WP:3.27 bp:0.53 mse:1.8083179896332489
# 623: WP:3.27 bp:0.53 mse:1.8083172111529098
# 624: WP:3.27 bp:0.53 mse:1.8083164332181598
# 625: WP:3.27 bp:0.53 mse:1.8083156558286186
# 626: WP:3.27 bp:0.53 mse:1.808314878983902
# 627: WP:3.27 bp:0.53 mse:1.808314102683629
# 628: WP:3.27 bp:0.53 mse:1.8083133269274156
# 629: WP:3.27 bp:0.53 mse:1.8083125517148864
# 630: WP:3.27 bp:0.53 mse:1.8083117770456563
# 631: WP:3.27 bp:0.53 mse:1.8083110029193439
# 632: WP:3.27 bp:0.53 mse:1.80831022933557
# 633: WP:3.27 bp:0.53 mse:1.8083094562939548
# 634: WP:3.27 bp:0.53 mse:1.8083086837941174
# 635: WP:3.27 bp:0.53 mse:1.8083079118356775
# 636: WP:3.27 bp:0.53 mse:1.8083071404182585
# 637: WP:3.27 bp:0.53 mse:1.8083063695414776
# 638: WP:3.27 bp:0.53 mse:1.8083055992049595
# 639: WP:3.27 bp:0.53 mse:1.808304829408324
# 640: WP:3.27 bp:0.53 mse:1.8083040601511924
# 641: WP:3.27 bp:0.53 mse:1.808303291433184
# 642: WP:3.27 bp:0.53 mse:1.8083025232539258
# 643: WP:3.27 bp:0.53 mse:1.8083017556130383
# 644: WP:3.27 bp:0.53 mse:1.8083009885101415
# 645: WP:3.27 bp:0.53 mse:1.8083002219448634
# 646: WP:3.27 bp:0.53 mse:1.808299455916825
# 647: WP:3.27 bp:0.53 mse:1.8082986904256473
# 648: WP:3.27 bp:0.53 mse:1.8082979254709564
# 649: WP:3.27 bp:0.53 mse:1.8082971610523788
# 650: WP:3.27 bp:0.53 mse:1.8082963971695347
# 651: WP:3.27 bp:0.53 mse:1.8082956338220475
# 652: WP:3.27 bp:0.53 mse:1.808294871009547
# 653: WP:3.27 bp:0.53 mse:1.8082941087316537
# 654: WP:3.27 bp:0.53 mse:1.8082933469879976
# 655: WP:3.27 bp:0.53 mse:1.8082925857781993
# 656: WP:3.27 bp:0.53 mse:1.8082918251018885
# 657: WP:3.27 bp:0.53 mse:1.8082910649586899
# 658: WP:3.27 bp:0.53 mse:1.8082903053482287
# 659: WP:3.27 bp:0.53 mse:1.8082895462701336
# 660: WP:3.27 bp:0.53 mse:1.8082887877240295
# 661: WP:3.27 bp:0.53 mse:1.8082880297095452
# 662: WP:3.27 bp:0.53 mse:1.808287272226308
# 663: WP:3.27 bp:0.53 mse:1.8082865152739431
# 664: WP:3.27 bp:0.53 mse:1.8082857588520829
# 665: WP:3.27 bp:0.53 mse:1.808285002960351
# 666: WP:3.27 bp:0.53 mse:1.8082842475983796
# 667: WP:3.27 bp:0.53 mse:1.8082834927657963
# 668: WP:3.27 bp:0.53 mse:1.8082827384622264
# 669: WP:3.27 bp:0.53 mse:1.8082819846873033
# 670: WP:3.27 bp:0.53 mse:1.8082812314406567
# 671: WP:3.27 bp:0.53 mse:1.808280478721915
# 672: WP:3.27 bp:0.53 mse:1.8082797265307102
# 673: WP:3.27 bp:0.53 mse:1.8082789748666679
# 674: WP:3.27 bp:0.53 mse:1.8082782237294233
# 675: WP:3.27 bp:0.53 mse:1.8082774731186058
# 676: WP:3.27 bp:0.53 mse:1.8082767230338443
# 677: WP:3.27 bp:0.53 mse:1.8082759734747722
# 678: WP:3.27 bp:0.53 mse:1.8082752244410225
# 679: WP:3.27 bp:0.53 mse:1.8082744759322245
# 680: WP:3.27 bp:0.53 mse:1.8082737279480094
# 681: WP:3.27 bp:0.53 mse:1.8082729804880142
# 682: WP:3.27 bp:0.53 mse:1.8082722335518648
# 683: WP:3.27 bp:0.53 mse:1.8082714871392007
# 684: WP:3.27 bp:0.53 mse:1.808270741249652
# 685: WP:3.27 bp:0.53 mse:1.8082699958828534
# 686: WP:3.27 bp:0.53 mse:1.8082692510384344
# 687: WP:3.27 bp:0.53 mse:1.8082685067160345
# 688: WP:3.27 bp:0.53 mse:1.8082677629152843
# 689: WP:3.27 bp:0.53 mse:1.808267019635819
# 690: WP:3.27 bp:0.53 mse:1.808266276877273
# 691: WP:3.27 bp:0.53 mse:1.8082655346392824
# 692: WP:3.27 bp:0.53 mse:1.808264792921479
# 693: WP:3.27 bp:0.53 mse:1.8082640517235034
# 694: WP:3.27 bp:0.53 mse:1.8082633110449897
# 695: WP:3.27 bp:0.53 mse:1.8082625708855706
# 696: WP:3.27 bp:0.53 mse:1.8082618312448873
# 697: WP:3.27 bp:0.53 mse:1.8082610921225701
# 698: WP:3.27 bp:0.53 mse:1.8082603535182615
# 699: WP:3.27 bp:0.53 mse:1.8082596154315942
# 700: WP:3.27 bp:0.53 mse:1.808258877862208
# 701: WP:3.27 bp:0.53 mse:1.808258140809741
# 702: WP:3.27 bp:0.53 mse:1.8082574042738269
# 703: WP:3.27 bp:0.53 mse:1.8082566682541097
# 704: WP:3.27 bp:0.53 mse:1.808255932750222
# 705: WP:3.27 bp:0.53 mse:1.8082551977618035
# 706: WP:3.27 bp:0.53 mse:1.8082544632884971
# 707: WP:3.27 bp:0.53 mse:1.8082537293299366
# 708: WP:3.27 bp:0.53 mse:1.8082529958857636
# 709: WP:3.27 bp:0.53 mse:1.8082522629556168
# 710: WP:3.27 bp:0.53 mse:1.8082515305391391
# 711: WP:3.27 bp:0.53 mse:1.8082507986359662
# 712: WP:3.27 bp:0.53 mse:1.8082500672457407
# 713: WP:3.27 bp:0.53 mse:1.8082493363681011
# 714: WP:3.27 bp:0.53 mse:1.808248606002689
# 715: WP:3.27 bp:0.53 mse:1.808247876149147
# 716: WP:3.27 bp:0.53 mse:1.8082471468071164
# 717: WP:3.27 bp:0.53 mse:1.8082464179762374
# 718: WP:3.27 bp:0.53 mse:1.8082456896561492
# 719: WP:3.27 bp:0.53 mse:1.8082449618465002
# 720: WP:3.27 bp:0.53 mse:1.808244234546926
# 721: WP:3.27 bp:0.53 mse:1.808243507757073
# 722: WP:3.27 bp:0.53 mse:1.8082427814765836
# 723: WP:3.27 bp:0.53 mse:1.8082420557051009
# 724: WP:3.27 bp:0.53 mse:1.8082413304422664
# 725: WP:3.27 bp:0.53 mse:1.8082406056877254
# 726: WP:3.27 bp:0.53 mse:1.8082398814411214
# 727: WP:3.27 bp:0.53 mse:1.8082391577021
# 728: WP:3.27 bp:0.53 mse:1.8082384344703009
# 729: WP:3.27 bp:0.53 mse:1.8082377117453727
# 730: WP:3.27 bp:0.53 mse:1.8082369895269574
# 731: WP:3.27 bp:0.53 mse:1.8082362678147001
# 732: WP:3.27 bp:0.53 mse:1.8082355466082511
# 733: WP:3.27 bp:0.53 mse:1.8082348259072505
# 734: WP:3.27 bp:0.53 mse:1.808234105711344
# 735: WP:3.27 bp:0.53 mse:1.8082333860201818
# 736: WP:3.27 bp:0.53 mse:1.8082326668334074
# 737: WP:3.27 bp:0.53 mse:1.8082319481506655
# 738: WP:3.27 bp:0.53 mse:1.8082312299716061
# 739: WP:3.27 bp:0.53 mse:1.8082305122958768
# 740: WP:3.27 bp:0.53 mse:1.8082297951231219
# 741: WP:3.27 bp:0.53 mse:1.8082290784529877
# 742: WP:3.27 bp:0.53 mse:1.8082283622851267
# 743: WP:3.27 bp:0.53 mse:1.8082276466191844
# 744: WP:3.27 bp:0.53 mse:1.8082269314548107
# 745: WP:3.27 bp:0.53 mse:1.8082262167916499
# 746: WP:3.27 bp:0.53 mse:1.8082255026293546
# 747: WP:3.27 bp:0.53 mse:1.8082247889675713
# 748: WP:3.27 bp:0.53 mse:1.8082240758059536
# 749: WP:3.27 bp:0.53 mse:1.8082233631441442
# 750: WP:3.27 bp:0.53 mse:1.808222650981798
# 751: WP:3.27 bp:0.53 mse:1.8082219393185637
# 752: WP:3.27 bp:0.53 mse:1.8082212281540884
# 753: WP:3.27 bp:0.53 mse:1.8082205174880295
# 754: WP:3.27 bp:0.53 mse:1.8082198073200297
# 755: WP:3.27 bp:0.53 mse:1.8082190976497463
# 756: WP:3.27 bp:0.53 mse:1.8082183884768268
# 757: WP:3.27 bp:0.53 mse:1.8082176798009264
# 758: WP:3.27 bp:0.53 mse:1.8082169716216925
# 759: WP:3.27 bp:0.53 mse:1.8082162639387767
# 760: WP:3.27 bp:0.53 mse:1.8082155567518365
# 761: WP:3.27 bp:0.53 mse:1.8082148500605182
# 762: WP:3.27 bp:0.53 mse:1.8082141438644774
# 763: WP:3.27 bp:0.53 mse:1.8082134381633688
# 764: WP:3.27 bp:0.53 mse:1.8082127329568405
# 765: WP:3.27 bp:0.53 mse:1.8082120282445528
# 766: WP:3.27 bp:0.53 mse:1.8082113240261535
# 767: WP:3.27 bp:0.53 mse:1.8082106203012973
# 768: WP:3.27 bp:0.53 mse:1.8082099170696389
# 769: WP:3.27 bp:0.53 mse:1.8082092143308353
# 770: WP:3.27 bp:0.53 mse:1.808208512084537
# 771: WP:3.27 bp:0.53 mse:1.8082078103304033
# 772: WP:3.27 bp:0.53 mse:1.8082071090680847
# 773: WP:3.27 bp:0.53 mse:1.8082064082972378
# 774: WP:3.27 bp:0.53 mse:1.80820570801752
# 775: WP:3.27 bp:0.53 mse:1.808205008228587
# 776: WP:3.27 bp:0.53 mse:1.8082043089300932
# 777: WP:3.27 bp:0.53 mse:1.8082036101216934
# 778: WP:3.27 bp:0.53 mse:1.8082029118030496
# 779: WP:3.27 bp:0.53 mse:1.8082022139738136
# 780: WP:3.27 bp:0.53 mse:1.8082015166336423
# 781: WP:3.27 bp:0.53 mse:1.8082008197821973
# 782: WP:3.27 bp:0.53 mse:1.8082001234191312
# 783: WP:3.27 bp:0.53 mse:1.8081994275441062
# 784: WP:3.27 bp:0.53 mse:1.8081987321567752
# 785: WP:3.27 bp:0.53 mse:1.8081980372568018
# 786: WP:3.27 bp:0.53 mse:1.8081973428438418
# 787: WP:3.27 bp:0.53 mse:1.8081966489175505
# 788: WP:3.27 bp:0.53 mse:1.8081959554775933
# 789: WP:3.27 bp:0.53 mse:1.8081952625236255
# 790: WP:3.27 bp:0.53 mse:1.808194570055309
# 791: WP:3.27 bp:0.53 mse:1.8081938780722997
# 792: WP:3.27 bp:0.53 mse:1.808193186574259
# 793: WP:3.27 bp:0.53 mse:1.8081924955608486
# 794: WP:3.27 bp:0.53 mse:1.8081918050317294
# 795: WP:3.27 bp:0.53 mse:1.8081911149865577
# 796: WP:3.27 bp:0.53 mse:1.8081904254249974
# 797: WP:3.27 bp:0.53 mse:1.8081897363467103
# 798: WP:3.27 bp:0.53 mse:1.8081890477513565
# 799: WP:3.27 bp:0.53 mse:1.8081883596385964
# 800: WP:3.27 bp:0.53 mse:1.808187672008095
# 801: WP:3.27 bp:0.53 mse:1.8081869848595093
# 802: WP:3.27 bp:0.53 mse:1.8081862981925074
# 803: WP:3.27 bp:0.53 mse:1.8081856120067474
# 804: WP:3.27 bp:0.53 mse:1.8081849263018934
# 805: WP:3.27 bp:0.53 mse:1.8081842410776108
# 806: WP:3.27 bp:0.53 mse:1.8081835563335578
# 807: WP:3.27 bp:0.53 mse:1.8081828720694026
# 808: WP:3.27 bp:0.53 mse:1.8081821882848066
# 809: WP:3.27 bp:0.53 mse:1.8081815049794319
# 810: WP:3.27 bp:0.53 mse:1.8081808221529447
# 811: WP:3.27 bp:0.53 mse:1.8081801398050115
# 812: WP:3.27 bp:0.53 mse:1.8081794579352943
# 813: WP:3.27 bp:0.53 mse:1.8081787765434576
# 814: WP:3.27 bp:0.53 mse:1.8081780956291675
# 815: WP:3.27 bp:0.53 mse:1.8081774151920909
# 816: WP:3.27 bp:0.53 mse:1.808176735231889
# 817: WP:3.27 bp:0.53 mse:1.8081760557482307
# 818: WP:3.27 bp:0.53 mse:1.808175376740784
# 819: WP:3.27 bp:0.53 mse:1.8081746982092082
# 820: WP:3.27 bp:0.53 mse:1.8081740201531769
# 821: WP:3.27 bp:0.53 mse:1.8081733425723545
# 822: WP:3.27 bp:0.53 mse:1.808172665466406
# 823: WP:3.27 bp:0.53 mse:1.8081719888350023
# 824: WP:3.27 bp:0.53 mse:1.8081713126778076
# 825: WP:3.27 bp:0.53 mse:1.8081706369944914
# 826: WP:3.27 bp:0.53 mse:1.808169961784718
# 827: WP:3.27 bp:0.53 mse:1.80816928704816
# 828: WP:3.27 bp:0.53 mse:1.8081686127844865
# 829: WP:3.27 bp:0.53 mse:1.8081679389933616
# 830: WP:3.27 bp:0.53 mse:1.8081672656744558
# 831: WP:3.27 bp:0.53 mse:1.8081665928274377
# 832: WP:3.27 bp:0.53 mse:1.8081659204519787
# 833: WP:3.27 bp:0.53 mse:1.8081652485477477
# 834: WP:3.27 bp:0.53 mse:1.808164577114413
# 835: WP:3.27 bp:0.53 mse:1.8081639061516463
# 836: WP:3.27 bp:0.53 mse:1.808163235659116
# 837: WP:3.27 bp:0.53 mse:1.8081625656364955
# 838: WP:3.27 bp:0.53 mse:1.80816189608345
# 839: WP:3.27 bp:0.53 mse:1.8081612269996568
# 840: WP:3.27 bp:0.53 mse:1.808160558384781
# 841: WP:3.27 bp:0.53 mse:1.808159890238499
# 842: WP:3.27 bp:0.53 mse:1.8081592225604801
# 843: WP:3.27 bp:0.53 mse:1.8081585553503983
# 844: WP:3.27 bp:0.53 mse:1.8081578886079217
# 845: WP:3.27 bp:0.53 mse:1.8081572223327222
# 846: WP:3.27 bp:0.53 mse:1.8081565565244795
# 847: WP:3.27 bp:0.53 mse:1.8081558911828575
# 848: WP:3.27 bp:0.53 mse:1.8081552263075373
# 849: WP:3.27 bp:0.53 mse:1.8081545618981851
# 850: WP:3.27 bp:0.53 mse:1.8081538979544771
# 851: WP:3.27 bp:0.53 mse:1.808153234476089
# 852: WP:3.27 bp:0.53 mse:1.8081525714626911
# 853: WP:3.27 bp:0.53 mse:1.8081519089139608
# 854: WP:3.27 bp:0.53 mse:1.8081512468295706
# 855: WP:3.27 bp:0.53 mse:1.808150585209196
# 856: WP:3.27 bp:0.53 mse:1.80814992405251
# 857: WP:3.27 bp:0.53 mse:1.80814926335919
# 858: WP:3.27 bp:0.53 mse:1.8081486031289087
# 859: WP:3.27 bp:0.53 mse:1.808147943361343
# 860: WP:3.27 bp:0.53 mse:1.8081472840561685
# 861: WP:3.27 bp:0.53 mse:1.8081466252130607
# 862: WP:3.27 bp:0.53 mse:1.808145966831699
# 863: WP:3.27 bp:0.53 mse:1.8081453089117534
# 864: WP:3.27 bp:0.53 mse:1.808144651452908
# 865: WP:3.27 bp:0.53 mse:1.8081439944548316
# 866: WP:3.27 bp:0.53 mse:1.8081433379172094
# 867: WP:3.27 bp:0.53 mse:1.8081426818397122
# 868: WP:3.27 bp:0.53 mse:1.8081420262220222
# 869: WP:3.27 bp:0.53 mse:1.8081413710638141
# 870: WP:3.27 bp:0.53 mse:1.8081407163647645
# 871: WP:3.27 bp:0.53 mse:1.8081400621245558
# 872: WP:3.27 bp:0.53 mse:1.8081394083428668
# 873: WP:3.27 bp:0.53 mse:1.8081387550193717
# 874: WP:3.27 bp:0.53 mse:1.8081381021537501
# 875: WP:3.27 bp:0.53 mse:1.8081374497456857
# 876: WP:3.27 bp:0.53 mse:1.8081367977948546
# 877: WP:3.27 bp:0.53 mse:1.8081361463009327
# 878: WP:3.27 bp:0.53 mse:1.8081354952636068
# 879: WP:3.27 bp:0.53 mse:1.8081348446825531
# 880: WP:3.27 bp:0.53 mse:1.808134194557452
# 881: WP:3.27 bp:0.53 mse:1.8081335448879845
# 882: WP:3.27 bp:0.53 mse:1.8081328956738325
# 883: WP:3.27 bp:0.53 mse:1.8081322469146726
# 884: WP:3.27 bp:0.53 mse:1.808131598610191
# 885: WP:3.27 bp:0.53 mse:1.8081309507600671
# 886: WP:3.27 bp:0.53 mse:1.8081303033639797
# 887: WP:3.27 bp:0.53 mse:1.8081296564216156
# 888: WP:3.27 bp:0.53 mse:1.808129009932653
# 889: WP:3.27 bp:0.53 mse:1.8081283638967776
# 890: WP:3.27 bp:0.53 mse:1.8081277183136668
# 891: WP:3.27 bp:0.53 mse:1.808127073183009
# 892: WP:3.27 bp:0.53 mse:1.8081264285044822
# 893: WP:3.27 bp:0.53 mse:1.8081257842777718
# 894: WP:3.27 bp:0.53 mse:1.8081251405025627
# 895: WP:3.27 bp:0.53 mse:1.808124497178534
# 896: WP:3.27 bp:0.53 mse:1.8081238543053757
# 897: WP:3.27 bp:0.53 mse:1.8081232118827664
# 898: WP:3.27 bp:0.53 mse:1.808122569910391
# 899: WP:3.27 bp:0.53 mse:1.808121928387938
# 900: WP:3.27 bp:0.53 mse:1.8081212873150891
# 901: WP:3.27 bp:0.53 mse:1.8081206466915278
# 902: WP:3.27 bp:0.53 mse:1.808120006516942
# 903: WP:3.27 bp:0.53 mse:1.8081193667910138
# 904: WP:3.27 bp:0.53 mse:1.8081187275134332
# 905: WP:3.27 bp:0.53 mse:1.8081180886838857
# 906: WP:3.27 bp:0.53 mse:1.8081174503020512
# 907: WP:3.27 bp:0.53 mse:1.8081168123676215
# 908: WP:3.27 bp:0.53 mse:1.8081161748802794
# 909: WP:3.27 bp:0.53 mse:1.808115537839716
# 910: WP:3.27 bp:0.53 mse:1.8081149012456164
# 911: WP:3.27 bp:0.53 mse:1.8081142650976674
# 912: WP:3.27 bp:0.53 mse:1.808113629395555
# 913: WP:3.27 bp:0.53 mse:1.8081129941389664
# 914: WP:3.27 bp:0.53 mse:1.8081123593275932
# 915: WP:3.27 bp:0.53 mse:1.808111724961119
# 916: WP:3.27 bp:0.53 mse:1.8081110910392348
# 917: WP:3.27 bp:0.53 mse:1.8081104575616302
# 918: WP:3.27 bp:0.53 mse:1.808109824527988
# 919: WP:3.27 bp:0.53 mse:1.8081091919380041
# 920: WP:3.27 bp:0.53 mse:1.8081085597913626
# 921: WP:3.27 bp:0.53 mse:1.8081079280877554
# 922: WP:3.27 bp:0.53 mse:1.80810729682687
# 923: WP:3.27 bp:0.53 mse:1.8081066660083993
# 924: WP:3.27 bp:0.53 mse:1.8081060356320293
# 925: WP:3.27 bp:0.53 mse:1.8081054056974513
# 926: WP:3.27 bp:0.53 mse:1.8081047762043596
# 927: WP:3.27 bp:0.53 mse:1.808104147152439
# 928: WP:3.27 bp:0.53 mse:1.8081035185413832
# 929: WP:3.27 bp:0.53 mse:1.8081028903708842
# 930: WP:3.27 bp:0.53 mse:1.8081022626406302
# 931: WP:3.27 bp:0.53 mse:1.808101635350317
# 932: WP:3.27 bp:0.54 mse:1.808101008499632
# 933: WP:3.27 bp:0.54 mse:1.8081003820882664
# 934: WP:3.27 bp:0.54 mse:1.808099756115918
# 935: WP:3.27 bp:0.54 mse:1.8080991305822744
# 936: WP:3.27 bp:0.54 mse:1.8080985054870322
# 937: WP:3.27 bp:0.54 mse:1.8080978808298795
# 938: WP:3.27 bp:0.54 mse:1.808097256610511
# 939: WP:3.27 bp:0.54 mse:1.8080966328286185
# 940: WP:3.27 bp:0.54 mse:1.8080960094839
# 941: WP:3.27 bp:0.54 mse:1.8080953865760445
# 942: WP:3.27 bp:0.54 mse:1.80809476410475
# 943: WP:3.27 bp:0.54 mse:1.8080941420697048
# 944: WP:3.27 bp:0.54 mse:1.8080935204706075
# 945: WP:3.27 bp:0.54 mse:1.808092899307152
# 946: WP:3.27 bp:0.54 mse:1.8080922785790339
# 947: WP:3.27 bp:0.54 mse:1.8080916582859443
# 948: WP:3.27 bp:0.54 mse:1.808091038427582
# 949: WP:3.27 bp:0.54 mse:1.8080904190036406
# 950: WP:3.27 bp:0.54 mse:1.808089800013816
# 951: WP:3.27 bp:0.54 mse:1.8080891814578035
# 952: WP:3.27 bp:0.54 mse:1.8080885633353
# 953: WP:3.27 bp:0.54 mse:1.8080879456459995
# 954: WP:3.27 bp:0.54 mse:1.8080873283896028
# 955: WP:3.27 bp:0.54 mse:1.8080867115658021
# 956: WP:3.27 bp:0.54 mse:1.808086095174297
# 957: WP:3.27 bp:0.54 mse:1.8080854792147842
# 958: WP:3.27 bp:0.54 mse:1.8080848636869575
# 959: WP:3.27 bp:0.54 mse:1.8080842485905204
# 960: WP:3.27 bp:0.54 mse:1.8080836339251638
# 961: WP:3.27 bp:0.54 mse:1.8080830196905915
# 962: WP:3.27 bp:0.54 mse:1.8080824058865
# 963: WP:3.27 bp:0.54 mse:1.808081792512586
# 964: WP:3.27 bp:0.54 mse:1.8080811795685463
# 965: WP:3.27 bp:0.54 mse:1.8080805670540834
# 966: WP:3.27 bp:0.54 mse:1.808079954968896
# 967: WP:3.27 bp:0.54 mse:1.8080793433126807
# 968: WP:3.27 bp:0.54 mse:1.8080787320851401
# 969: WP:3.27 bp:0.54 mse:1.80807812128597
# 970: WP:3.27 bp:0.54 mse:1.8080775109148715
# 971: WP:3.27 bp:0.54 mse:1.8080769009715485
# 972: WP:3.27 bp:0.54 mse:1.8080762914556967
# 973: WP:3.27 bp:0.54 mse:1.8080756823670179
# 974: WP:3.27 bp:0.54 mse:1.8080750737052134
# 975: WP:3.27 bp:0.54 mse:1.8080744654699812
# 976: WP:3.27 bp:0.54 mse:1.8080738576610254
# 977: WP:3.27 bp:0.54 mse:1.8080732502780466
# 978: WP:3.27 bp:0.54 mse:1.8080726433207424
# 979: WP:3.27 bp:0.54 mse:1.8080720367888228
# 980: WP:3.27 bp:0.54 mse:1.8080714306819814
# 981: WP:3.27 bp:0.54 mse:1.8080708249999258
# 982: WP:3.27 bp:0.54 mse:1.808070219742355
# 983: WP:3.27 bp:0.54 mse:1.8080696149089723
# 984: WP:3.27 bp:0.54 mse:1.808069010499482
# 985: WP:3.27 bp:0.54 mse:1.8080684065135857
# 986: WP:3.27 bp:0.54 mse:1.8080678029509853
# 987: WP:3.27 bp:0.54 mse:1.8080671998113862
# 988: WP:3.27 bp:0.54 mse:1.8080665970944931
# 989: WP:3.27 bp:0.54 mse:1.8080659948000057
# 990: WP:3.27 bp:0.54 mse:1.8080653929276298
# 991: WP:3.27 bp:0.54 mse:1.8080647914770713
# 992: WP:3.27 bp:0.54 mse:1.8080641904480332
# 993: WP:3.27 bp:0.54 mse:1.8080635898402193
# 994: WP:3.27 bp:0.54 mse:1.8080629896533358
# 995: WP:3.27 bp:0.54 mse:1.8080623898870867
# 996: WP:3.27 bp:0.54 mse:1.8080617905411769
# 997: WP:3.27 bp:0.54 mse:1.8080611916153126
# 998: WP:3.27 bp:0.54 mse:1.8080605931092009
# 999: WP:3.27 bp:0.54 mse:1.8080599950225436
# 1000: WP:3.27 bp:0.54 mse:1.80805939735505

# %%
# 예측하기
tx = [[3],[7],[12],[15]]
ty = []
for tex in tx:
  ty.append(tex[0]*wp+bp)
print(ty)
# Out:
# [10.33401624523757, 23.39715254739143, 39.726072925083756, 49.52342515169915]

# %%
ntx = np.array(tx).reshape(-1)
plt.figure(figsize=(4,4))
plt.plot(xs,ys,'o',label='train data')
plt.plot(ntx,ty,'*',label='predict data')
plt.plot([0,50],[wp*0+bp,wp*50+bp],label=f'y={wp:.2f}+{bp:.2f}')
plt.xlim(0,50)
plt.ylim(0,50)
plt.legend()
plt.show()

# %%
for i,(w,b) in enumerate(wbhl):
  plt.figure(figsize=(4,4))
  plt.plot(xs,ys,'o',label='train data')
  plt.plot(ntx,ty,'*',label='predict data')
  plt.plot([0,50],[w*0+b,w*50+b],'-r',label=f"y={w:.2f}+{b:.2f}")
  plt.xlim(0,50)
  plt.ylim(0,50)
  plt.legend()
  plt.title(str(i))
  plt.show()
  if i == 50:
    break

# %% [markdown]
# * 머신러닝의 선형 회귀 맛보기
#
# 사이킷런 사이트:http://scikit-learn.org/stable/

# %%
from sklearn.datasets import load_boston
data = load_boston()
xs = data['data']
ys = data['target']

# %%
columns = data['feature_names']
columns
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df = pd.DataFrame(xs)
df.columns = columns
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
s = pd.Series(ys)
s

# %%
xs = df[['AGE','CRIM','LSTAT','RM']]
xs.head()
# Out:
#     AGE     CRIM  LSTAT     RM
# 0  65.2  0.00632   4.98  6.575
# 1  78.9  0.02731   9.14  6.421
# 2  61.1  0.02729   4.03  7.185
# 3  45.8  0.03237   2.94  6.998
# 4  54.2  0.06905   5.33  7.147

# %%
s.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression() #모델 생성
model.fit(xs,s) # 학습해
print(f"{model.coef_},{model.intercept_}")
# Out:
# [ 0.01259342 -0.10638575 -0.61257821  5.11624558],-2.349101143530042

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(xs,s)

# %%
model = LinearRegression() #모델 생성
model.fit(x_train,y_train) # 학습해
print(f"{model.coef_},{model.intercept_}")
# Out:
# [ 0.01057324 -0.11457651 -0.56820079  5.29944538],-3.9915668480930897

# %%
yps = model.predict(x_test)
for y,yp in zip(y_train,yps):
  print(f"{y:.2f},{yp:.2f}")

# %%
xs2.shape
# Out:
# (6,)

# %%
xs = [[2],[4],[9],[5],[3],[6]] # 특성이 하나로 구성된 독립변수 목록
ys = [8,12,31,15,12,20] # 종속변수 목록
model = LinearRegression()  # 모델 생성
model.fit(xs, ys) # 학습해
print(f"{model.coef_},{model.intercept_}")
# Out:
# [3.25405405],0.6054054054054046

# %%
# !pip install ColabTurtlePlus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ColabTurtlePlus in /usr/local/lib/python3.7/dist-packages (2.0.1)

# %%
from ColabTurtlePlus import Turtle
Turtle.initializeTurtle()
Turtle.setup(width=200,height=200)
Turtle.shape('turtle')
Turtle.speed(1)
Turtle.forward(50)
Turtle.left(45)
Turtle.right(90)
Turtle.left(90)
Turtle.right(90)
Turtle.left(90)
Turtle.right(45)
Turtle.left(180)
Turtle.forward(110)
Turtle.left(180)
Turtle.forward(50)
Turtle.left(90)
Turtle.right(90)
Turtle.left(90)
Turtle.right(90)
Turtle.left(90)
Turtle.right(90)
Turtle.left(180)
# Out:
#       <svg width="200" height="200">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="100.0" y1="100.0" x2="150.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="150.0" y1="100.0" x2="40.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="40.0" y1="100.0" x2="90.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90,90.0,100.0) translate(90.0, 100.0)">
# <path style="stroke:black;fill-rule:evenodd;fill:black;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# <animateTransform id = "one" attributeName="transform"
#                       type="scale"
#                       from="1 1" to="1 1"
#                       begin="0s" dur="0.01s"
#                       repeatCount="1"
#                       additive="sum"
#                       fill="freeze"
#                 /><animateTransform attributeName="transform"
#                     type="rotate"
#                     from="0 0 0" to ="-180 0 0"
#                     begin="one.end" dur="2.0s"
#                     repeatCount="1"
#                     additive="sum"
#                     fill="freeze"
#                 /></g>
#       </svg>

# %%
print(Turtle.position())
# Out:
# (-10.0, 0.0)

# %%
from ColabTurtlePlus import Turtle
Turtle.initializeTurtle()
Turtle.setup(width=200,height=200)
Turtle.shape('turtle')
Turtle.goto(80,0)
Turtle.left(90)
Turtle.goto(0,80)
Turtle.left(90)
Turtle.goto(0,80)
Turtle.left(90)
Turtle.goto(0,0)
Turtle.sety(50)
Turtle.home()
# Out:
#       <svg width="200" height="200">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="100.0" y1="100.0" x2="180.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="180.0" y1="100.0" x2="100.0" y2="20.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="20.0" x2="100.0" y2="20.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="20.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="100.0" x2="100.0" y2="50.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="50.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90.0,100.0,100.0) translate(100.0, 100.0)">
# <path style="stroke:black;fill-rule:evenodd;fill:black;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# </g>
#       </svg>

# %%
Turtle.initializeTurtle()
Turtle.setup(width=200,height=200)
Turtle.hideturtle()
Turtle.shape('turtle')
Turtle.goto(80,0)
Turtle.showturtle()
Turtle.left(90)
Turtle.goto(0,80)
Turtle.left(90)
Turtle.goto(0,80)
Turtle.left(90)
Turtle.goto(0,0)
Turtle.sety(50)
Turtle.home()
# Out:
#       <svg width="200" height="200">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="100.0" y1="100.0" x2="180.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="180.0" y1="100.0" x2="100.0" y2="20.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="20.0" x2="100.0" y2="20.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="20.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="100.0" x2="100.0" y2="50.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="50.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90.0,100.0,100.0) translate(100.0, 100.0)">
# <path style="stroke:black;fill-rule:evenodd;fill:black;fill-opacity:1;" transform="skewX(0) scale(1,1)" d="m 1.1536693,-18.56101 c -2.105469,1.167969 -3.203125,3.441407 -3.140625,6.5 l 0.011719,0.519532 -0.300782,-0.15625 c -1.308594,-0.671875 -2.828125,-0.824219 -4.378906,-0.429688 -1.9375,0.484375 -3.8906253,2.089844 -6.0117193,4.9257825 -1.332031,1.785156 -1.714843,2.644531 -1.351562,3.035156 l 0.113281,0.125 h 0.363281 c 0.71875,0 1.308594,-0.265625 4.6679693,-2.113282 1.199219,-0.660156 2.183594,-1.199218 2.191406,-1.199218 0.00781,0 -0.023437,0.089844 -0.074218,0.195312 -0.472657,1.058594 -1.046876,2.785156 -1.335938,4.042969 -1.054688,4.574219 -0.351562,8.453125 2.101562,11.582031 0.28125,0.355469 0.292969,0.253906 -0.097656,0.722656 -2.046875,2.4609375 -3.027344,4.8984375 -2.734375,6.8046875 0.050781,0.339844 0.042969,0.335938 0.679688,0.335938 2.023437,0 4.15625,-1.316407 6.21875,-3.835938 0.222656,-0.269531 0.191406,-0.261719 0.425781,-0.113281 0.730469,0.46875 2.460938,1.390625 2.613281,1.390625 0.160157,0 1.765625,-0.753906 2.652344,-1.246094 0.167969,-0.09375 0.308594,-0.164062 0.308594,-0.160156 0.066406,0.105468 0.761719,0.855468 1.085937,1.171875 1.613282,1.570312 3.339844,2.402343 5.3593747,2.570312 0.324219,0.02734 0.355469,0.0078 0.425781,-0.316406 0.375,-1.742187 -0.382812,-4.058594 -2.1445307,-6.5585935 l -0.320312,-0.457031 0.15625,-0.183594 c 3.2460927,-3.824218 3.4335927,-9.08593704 0.558593,-15.816406 l -0.050781,-0.125 1.7382807,0.859375 c 3.585938,1.773437 4.371094,2.097656 5.085938,2.097656 0.945312,0 0.75,-0.863281 -0.558594,-2.507812 C 11.458356,-11.838353 8.3333563,-13.268041 4.8607003,-11.721166 l -0.363281,0.164063 0.019531,-0.09375 c 0.121094,-0.550781 0.183594,-1.800781 0.121094,-2.378907 -0.203125,-1.867187 -1.035157,-3.199218 -2.695313,-4.308593 -0.523437,-0.351563 -0.546875,-0.355469 -0.789062,-0.222657" />
# </g>
#       </svg>

# %%
# 거북이 모양으로 변경
Turtle.shape("turtle")

angle = 89           # 거북이가 왼쪽으로 회전할 각도를 지정
Turtle.bgcolor("black")   # 배경색을 검은색으로 지정
Turtle.color("green")     # 펜 색을 녹색으로 지정
Turtle.speed(0)           # 거북이 속도를 가장 빠르게 지정
for x in range(200): # x 값을 0에서 199까지 바꾸면서 200번 실행
    Turtle.forward(x)     # x 만큼 앞으로 이동 (실행을 반복하면서 선이 
    길어짐)
    Turtle.left(angle)    # 거북이가 왼쪽으로 89도 회전

Turtle.hideturtle();      # 거북이를 화면에 보이지 않도록 숨긴다.

# Run -> Run Module (F5) 선택하여 실행

# %% [markdown]
# python-docx 메뉴얼 사이트:
# https://python-docx.readthedocs.io/en/latest/

# %%
# !pip install python-docx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 5.3 MB/s
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx) (4.9.1)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=76879262e48dffaaed28860b694211e1bae07470adcc3215c3498d3bbe3169ef
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11

# %%
from docx import Document

# %%
doc = Document() # 문서 개체 생성
doc.add_heading("문서 자동화 테스트 파일") # 헤더 추가
doc.add_paragraph('안녕하세요.') # 단락 추가
doc.save('demo.docx')

# %%
doc1 = Document() # 문서 개체 생성
doc1.add_heading('Doc1')
doc1.save('doc1.docx')
doc2 = Document('doc1.docx') # 존재하는 파일 명으로 문서 개체 생성
doc2.add_paragraph('새로운 단락을 추가') # 단락 추가
doc2.save('doc2.docx')

# %% [markdown]
# * Document 멤버

# %%
# 제공 메서드
# add_heading(text=u'', level=1)
# add_page_break()
# add_paragraph(text=u'', style=None)
# add_picture(image_path_or_stream, width=None, height=None)
# add_section(start_type=2)
# add_table(rows, cols, style=None)
# save(path_or_stream)
# 제공 필드( 속성 )
# core_properties
# inline_shapes
# paragraphs
# part
# save(path_or_stream)
# sections
# settings
# styles
# tables

# %%
doc = Document()
doc.add_paragraph() # 빈 단락 추가
doc.add_paragraph('두 번째 단락') # 단락 추가
normal_style = doc.styles['Normal']
doc.add_paragraph('세 번째 단락', style=normal_style) 
doc.save('para1.docx')

# %%
from docx.enum.style import WD_STYLE_TYPE
doc = Document()
for style in doc.styles:
  if style.type == WD_STYLE_TYPE.PARAGRAPH:
    doc.add_paragraph(style.name,style=style)
doc.save('para2.docx')

# %%
from docx.enum.text import WD_ALIGN_PARAGRAPH
doc = Document()
para = doc.add_paragraph('단락1 입니다.')
para.add_run("현재 단락에 run을 추가합니다.")
para.alignment = WD_ALIGN_PARAGRAPH.CENTER
doc.add_paragraph("단락2 입니다.")
doc.add_paragraph("단락3 입니다.")
doc.save("para3.docx")

# %%
doc = Document()
doc.add_heading("테이블사용") 
table2 = doc.add_table(2,5,gs) #2행 5열 테이블 생성
for r in range(len(table.rows)):
  row = table2.rows[r]
  for c in range(len(row.cells)):
    cell = row.cells[c]
    cell.text = f"{r},{c}"
doc.save('table2.docx')

# %%
doc = Document()
doc.add_heading("테이블사용") 
gs = Document().styles["Table Grid"]
table = doc.add_table(2,5,gs) #2행 5열 테이블 생성
for r in range(len(table.rows)):
  row = table.rows[r]
  for c in range(len(row.cells)):
    cell = row.cells[c]
    cell.text = f"{r},{c}"
doc.save('table1.docx')

# %%
from docx import Document
from docx.enum.style import WD_STYLE_TYPE

styles = Document().styles
for style in styles:
  if style.type == WD_STYLE_TYPE.TABLE:
    print(style.name)
gs = Document().styles['Table Grid']
print(gs.name)

# %%
from docx.shared import Inches
doc = Document()
doc.add_heading("테이블사용") 
gs = Document().styles["Table Grid"]
table = doc.add_table(2,5,gs) #2행 5열 테이블 생성
for r in range(len(table.rows)):
  row = table.rows[r]
  for c in range(len(row.cells)):
    cell = row.cells[c]
    cell.text = f"{r},{c}"
cell = table.cell(0,0)
para = cell.add_paragraph()
run = para.add_run()
run.add_picture('/content/주차.png', width=Inches(1),height=Inches(1))

cell2 = table.cell(1,0)
cell2.width=Inches(4) # cell로 height는 변경할 수 없는 것 같은 느낌적인 느낌
table.rows[1].height=Inches(4)
doc.save('table3.docx')
